# %%
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt

# %%
file_path = r'C:\Users\tiara.santoso\Downloads\Data Exports\yougov_beauty_persona.xlsx'
sheet_name = 'All'
df = pd.read_excel(file_path, sheet_name=sheet_name)
df.head()
# Out:
#         person_id  \
# 0  EMEA:225372842
# 1  EMEA:207135884
# 2  EMEA:122918932
# 3  EMEA:125295120
# 4  EMEA:123796730
#
#    I believe that physical and mental health have impact to my skin condition  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    I like to purchase beauty products that give added emotional benefit (i.e. relaxation, calming, mood uplift)  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    I like to purchase beauty products that is simple and easy to use.  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    I prefer Beauty Brands that helps me find the product i need (i.e. Skin Test tools for checking skin condition and provide recommendation, AI to help customize foundation color to my skin)  \
# 0                                                  3
# 1                                                  3
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    I like to try newest trends in beauty industries  \
# 0                                                 4
# 1                                                 3
# 2                                                 4
# 3                                                 3
# 4                                                 3
#
#    I like beauty products that give result like beauty treatment, as effective as beauty clinics  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    I prefer to use beauty products that using renewable natural resources, to protect nature's sustainability  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    I prefer beauty brand that has clear actions / helps me participate in sustainability (i.e. fair trade sourcing, natural, organic ingredients / materials).  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    I try to minimize waste that I produce from beauty products (ex. by purchase refill and dispose empty packaging to recycling station)  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I choose beauty brands that have CSR program to support local  people/community advancement (ie. give education about health, sourcing dissability people in company, etc)  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    I choose Beauty brands that represent various Indonesian beauty standards (ex. provide various foundation shade for Indonesian's skin color, Brand Ambassador from various background)  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    I choose a beauty brand that is in line with the values / principles that I believe in  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    I use beauty products to express my personal identity  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    I am attracted to beauty products that have unique variant or limited edition  \
# 0                                                  2
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    I like to experiment with looks
# 0                                3
# 1                                2
# 2                                4
# 3                                4
# 4                                3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 16 columns):
#  #   Column                                                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                        --------------  -----
#  0   person_id                                                                                                                                                                                     2300 non-null   object
#  1   I believe that physical and mental health have impact to my skin condition                                                                                                                    2300 non-null   int64
#  2   I like to purchase beauty products that give added emotional benefit (i.e. relaxation, calming, mood uplift)                                                                                  2300 non-null   int64
#  3   I like to purchase beauty products that is simple and easy to use.                                                                                                                            2300 non-null   int64
#  4   I prefer Beauty Brands that helps me find the product i need (i.e. Skin Test tools for checking skin condition and provide recommendation, AI to help customize foundation color to my skin)  2300 non-null   int64
#  5   I like to try newest trends in beauty industries                                                                                                                                              2300 non-null   int64
#  6   I like beauty products that give result like beauty treatment, as effective as beauty clinics                                                                                                 2300 non-null   int64
#  7   I prefer to use beauty products that using renewable natural resources, to protect nature's sustainability                                                                                    2300 non-null   int64
#  8   I prefer beauty brand that has clear actions / helps me participate in sustainability (i.e. fair trade sourcing, natural, organic ingredients / materials).                                   2300 non-null   int64
#  9   I try to minimize waste that I produce from beauty products (ex. by purchase refill and dispose empty packaging to recycling station)                                                         2300 non-null   int64
#  10  I choose beauty brands that have CSR program to support local  people/community advancement (ie. give education about health, sourcing dissability people in company, etc)                    2300 non-null   int64
#  11  I choose Beauty brands that represent various Indonesian beauty standards (ex. provide various foundation shade for Indonesian's skin color, Brand Ambassador from various background)        2300 non-null   int64
#  12  I choose a beauty brand that is in line with the values / principles that I believe in                                                                                                        2300 non-null   int64
#  13  I use beauty products to express my personal identity                                                                                                                                         2300 non-null   int64
#  14  I am attracted to beauty products that have unique variant or limited edition                                                                                                                 2300 non-null   int64
#  15  I like to experiment with looks                                                                                                                                                               2300 non-null   int64
# dtypes: int64(15), object(1)
# memory usage: 287.6+ KB

# %%
from sklearn.preprocessing import StandardScaler

df.set_index('person_id', inplace=True)

scaler = StandardScaler()
# df_scaled = df.drop(columns=['person_id'])
scaled_data = scaler.fit_transform(df)

# %%
print(scaled_data)
# Out:
# [[-1.62756996 -2.13778318 -1.9174159  ... -0.88584556 -1.18871021
#   -0.12434293]
#  [-0.22659282 -0.89457172 -0.37651563 ... -0.88584556 -1.18871021
#   -1.13490384]
#  [-0.22659282  0.34863974 -0.37651563 ...  0.3385804   1.04133341
#    0.88621798]
#  ...
#  [-1.62756996 -0.89457172  1.16438464 ... -0.88584556 -2.30373201
#   -1.13490384]
#  [-0.22659282  0.34863974  1.16438464 ... -0.88584556  1.04133341
#    0.88621798]
#  [-0.22659282  0.34863974  1.16438464 ...  0.3385804  -1.18871021
#   -0.12434293]]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
kmeans.fit(scaled_data)

df['Cluster'] = kmeans.labels_
# Out:
# C:\Users\tiara.santoso\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df.head()
# Out:
#                 I believe that physical and mental health have impact to my skin condition  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  3
# EMEA:123796730                                                  5
#
#                 I like to purchase beauty products that give added emotional benefit (i.e. relaxation, calming, mood uplift)  \
# person_id
# EMEA:225372842                                                  2
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  4
#
#                 I like to purchase beauty products that is simple and easy to use.  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  5
#
#                 I prefer Beauty Brands that helps me find the product i need (i.e. Skin Test tools for checking skin condition and provide recommendation, AI to help customize foundation color to my skin)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  5
# EMEA:125295120                                                  4
# EMEA:123796730                                                  4
#
#                 I like to try newest trends in beauty industries  \
# person_id
# EMEA:225372842                                                 4
# EMEA:207135884                                                 3
# EMEA:122918932                                                 4
# EMEA:125295120                                                 3
# EMEA:123796730                                                 3
#
#                 I like beauty products that give result like beauty treatment, as effective as beauty clinics  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  4
#
#                 I prefer to use beauty products that using renewable natural resources, to protect nature's sustainability  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  5
#
#                 I prefer beauty brand that has clear actions / helps me participate in sustainability (i.e. fair trade sourcing, natural, organic ingredients / materials).  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  5
#
#                 I try to minimize waste that I produce from beauty products (ex. by purchase refill and dispose empty packaging to recycling station)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  4
#
#                 I choose beauty brands that have CSR program to support local  people/community advancement (ie. give education about health, sourcing dissability people in company, etc)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  5
#
#                 I choose Beauty brands that represent various Indonesian beauty standards (ex. provide various foundation shade for Indonesian's skin color, Brand Ambassador from various background)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  5
#
#                 I choose a beauty brand that is in line with the values / principles that I believe in  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  5
#
#                 I use beauty products to express my personal identity  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  3
#
#                 I am attracted to beauty products that have unique variant or limited edition  \
# person_id
# EMEA:225372842                                                  2
# EMEA:207135884                                                  2
# EMEA:122918932                                                  4
# EMEA:125295120                                                  3
# EMEA:123796730                                                  4
#
#                 I like to experiment with looks  Cluster
# person_id
# EMEA:225372842                                3        4
# EMEA:207135884                                2        3
# EMEA:122918932                                4        1
# EMEA:125295120                                4        0
# EMEA:123796730                                3        2

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 6))
for cluster_label in range(5): 
    cluster_points = scaled_data[df['Cluster'] == cluster_label]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster_label}', alpha=0.5)

    # Compute centroid of the cluster
    centroid = np.mean(cluster_points, axis=0)
    
    # Connect data points to centroid
    for point in cluster_points:
        plt.plot([centroid[0], point[0]], [centroid[1], point[1]], linestyle='-', color='gray', alpha=0.3)

    # Plot centroid
    plt.plot(centroid[0], centroid[1], marker='o', markersize=8, color='black')

plt.title('KMeans Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.manifold import TSNE

# Reduce the dimensionality of the data to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
tsne_data = tsne.fit_transform(scaled_data)

# Plotting clusters using t-SNE
plt.figure(figsize=(8, 6))
for cluster_label in range(5): 
    cluster_points = tsne_data[df['Cluster'] == cluster_label]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster_label}', alpha=0.5)

    # Compute centroid of the cluster
    centroid = np.mean(cluster_points, axis=0)
    
    # Connect data points to centroid
    for point in cluster_points:
        plt.plot([centroid[0], point[0]], [centroid[1], point[1]], linestyle='-', color='gray', alpha=0.3)

    # Plot centroid
    plt.plot(centroid[0], centroid[1], marker='o', markersize=8, color='black')

plt.title('KMeans Clustering with t-SNE')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#                 I believe that physical and mental health have impact to my skin condition  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  3
# EMEA:123796730                                                  5
#
#                 I like to purchase beauty products that give added emotional benefit (i.e. relaxation, calming, mood uplift)  \
# person_id
# EMEA:225372842                                                  2
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  4
#
#                 I like to purchase beauty products that is simple and easy to use.  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  5
#
#                 I prefer Beauty Brands that helps me find the product i need (i.e. Skin Test tools for checking skin condition and provide recommendation, AI to help customize foundation color to my skin)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  5
# EMEA:125295120                                                  4
# EMEA:123796730                                                  4
#
#                 I like to try newest trends in beauty industries  \
# person_id
# EMEA:225372842                                                 4
# EMEA:207135884                                                 3
# EMEA:122918932                                                 4
# EMEA:125295120                                                 3
# EMEA:123796730                                                 3
#
#                 I like beauty products that give result like beauty treatment, as effective as beauty clinics  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  4
#
#                 I prefer to use beauty products that using renewable natural resources, to protect nature's sustainability  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  5
#
#                 I prefer beauty brand that has clear actions / helps me participate in sustainability (i.e. fair trade sourcing, natural, organic ingredients / materials).  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  5
#
#                 I try to minimize waste that I produce from beauty products (ex. by purchase refill and dispose empty packaging to recycling station)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  4
#
#                 I choose beauty brands that have CSR program to support local  people/community advancement (ie. give education about health, sourcing dissability people in company, etc)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  5
#
#                 I choose Beauty brands that represent various Indonesian beauty standards (ex. provide various foundation shade for Indonesian's skin color, Brand Ambassador from various background)  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  5
#
#                 I choose a beauty brand that is in line with the values / principles that I believe in  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  4
# EMEA:122918932                                                  4
# EMEA:125295120                                                  4
# EMEA:123796730                                                  5
#
#                 I use beauty products to express my personal identity  \
# person_id
# EMEA:225372842                                                  3
# EMEA:207135884                                                  3
# EMEA:122918932                                                  4
# EMEA:125295120                                                  5
# EMEA:123796730                                                  3
#
#                 I am attracted to beauty products that have unique variant or limited edition  \
# person_id
# EMEA:225372842                                                  2
# EMEA:207135884                                                  2
# EMEA:122918932                                                  4
# EMEA:125295120                                                  3
# EMEA:123796730                                                  4
#
#                 I like to experiment with looks  Cluster
# person_id
# EMEA:225372842                                3        4
# EMEA:207135884                                2        3
# EMEA:122918932                                4        1
# EMEA:125295120                                4        0
# EMEA:123796730                                3        2

# %%
df.to_excel('20240320-result_beauty_persona_main_and_booster.xlsx',index=True)
