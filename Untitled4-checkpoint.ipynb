# %%
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt
file_path = r'C:\Users\tiara.santoso\Downloads\Data Exports\test_data_for_store_clustering_2.0.xlsx'

# %%
df = pd.read_excel(file_path, sheet_name = 'All Data')
df.head()
# Out:
#                            store_name  net_rev_monthly  after_discount  \
# 0            Sociolla Lippo Mall Puri       2283757349      2622787612
# 1               Sociolla Pakuwon Mall       2548571915      2960244908
# 2         Sociolla Summarecon Serpong       2211739674      2534646325
# 3  Sociolla Lippo Mall Kemang Village       1588809712      1807625526
# 4             Sociolla Sunplaza Medan       2627900688      3004533618
#
#    percentage_disc_to_nmv  aov_average  order_count  quantity_count  \
# 0                  0.2282       307977         8516           27521
# 1                  0.2292       245521        12057           34310
# 2                  0.2291       245065        10343           30160
# 3                  0.2137       298699         6052           19725
# 4                  0.2000       255310        11768           35553
#
#    unique_shoppers  guest_order_proportion  store_size  ...  online_order  \
# ...

# %%
df.dtypes
# Out:
# store_name                       object
# net_rev_monthly                   int64
# after_discount                    int64
# percentage_disc_to_nmv          float64
# aov_average                       int64
# order_count                       int64
# quantity_count                    int64
# unique_shoppers                   int64
# guest_order_proportion          float64
# store_size                        int64
# sales_per_sqm                   float64
# store_life                        int64
# cat_skincare                    float64
# cat_makeup                      float64
# cat_bath_and_body               float64
# cat_haircare                    float64
# cat_accessories                 float64
# cat_fragrance                   float64
# area_category                    object
# city_type                        object
# aovdis<=50k                     float64
# aovdis50-100k                   float64
# aovdis100-200k                  float64
# ...

# %%
df.dtypes
# Out:
# store_name                       object
# net_rev_monthly                   int64
# after_discount                    int64
# percentage_disc_to_nmv          float64
# aov_average                       int64
# order_count                       int64
# quantity_count                    int64
# unique_shoppers                   int64
# guest_order_proportion          float64
# store_size                        int64
# sales_per_sqm                   float64
# store_life                        int64
# cat_skincare                    float64
# cat_makeup                      float64
# cat_bath_and_body               float64
# cat_haircare                    float64
# cat_accessories                 float64
# cat_fragrance                   float64
# area_category                    object
# city_type                        object
# aovdis<=50k                     float64
# aovdis50-100k                   float64
# aovdis100-200k                  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# Assuming 'area_category' and 'city_type' are the categorical columns
categorical_columns = ['area_category', 'city_type']

# One-hot encode categorical columns
df_encoded = pd.get_dummies(df, columns=categorical_columns)

# Calculate the correlation matrix
correlation_matrix = df_encoded.corr()

# Create a heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(original_data_encoded, cmap='viridis', annot=False)
plt.title('Original Variables Heatmap')
plt.xlabel('Original Variables')
plt.ylabel('Store Names')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(12, 8))
# ----> 2 sns.heatmap(original_data_encoded, cmap='viridis', annot=False)
#       3 plt.title('Original Variables Heatmap')
#       4 plt.xlabel('Original Variables')
#
# NameError: name 'original_data_encoded' is not defined
